# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), 'log_dir')
os.makedirs(logs_dir, exist_ok=True)

# %%
# Name of the log file with timestamp
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"
LOG_FILE
# Out:
# '08_05_2025_01_51_04.log'

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)
LOG_FILE_PATH
# Out:
# 'c:\\Users\\ARSHPARAM\\tanya\\Document_Portal\\notebook\\log_dir\\08_05_2025_01_51_04.log'

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format='[ %(asctime)s ] - %(levelname)s -(name)s  (line:%(lineno)d) -  %(message)s',
    level =logging.INFO)

logger = logging.getLogger("Document_Portal")
logger.info('This is an info message')

# %%
import structlog
logger = structlog.get_logger()

# %%
logger.info("Implemnetion of structlog complete.", user_id = 123, action="login", status="success")
# Out:
# 2025-08-05 01:51:04 [info     ] Implemnetion of structlog complete. action=login status=success user_id=123
